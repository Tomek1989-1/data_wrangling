# %% [markdown]
# **Conclusions:**

# %% [markdown]
# - In regards to the average rating, average number of retweets and average number of people who liked the tweet the puppo stage performed the best.<br>
# - The pupper stage is the one that performed the worst in view of average rating and average number of retweets.<br>
# - The floofer stage is the one that performed the worst in view of average number of likes.<br>
# - Siberian_husky, borzoi and Samoyed are the breeds that had the highest average rating for breeds that appeared more than 10 times.<br>
# - standard_poodle, whippet and Cardigan are the breeds that had the highest average number of retweets for breeds that appeared more than 10 times.<br>
# - standard_poodle, French_bulldog and basset are the breeds that had the highest average number of likes for breeds that appeared more than 10 times.

# %% [markdown]
# The very interesting thing is that the number of retweets and likes is with no doubts correlated with the rating of a tweet as we can find in below visualizations. One of the explanations why it happens is that people are not as much willing to share and like tweets with poor rating. It might also suggest that the author of a tweet can influence (to some extent) the number of shares and likes the particular tweet will receive by labelling them with high/low rating.

# %%
df_master.plot(x='rating_numerator',y='retweet_count',kind='scatter', title='number of retweets in relation to rating for each tweet', size=(12,8));

# %%
df_master.plot(x='rating_numerator',y='favorite_count',kind='scatter', title='number of likes in relation to rating for each tweet');
